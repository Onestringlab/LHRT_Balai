# %%
import os
import numpy as np
import pandas as pd

# %%
def read_excel(path):
    return pd.read_excel(path)

def koefisien(df):
    data.loc[:, 'KOEFISIEN'] = data['SMP'] / data['SMP'].max()
    return data

# %%
path_1 = '../Data/Preprocessing/Data Balonggandu/2023/4_lhrt_normalisasi_balonggandu_2023.xlsx'
df = read_excel(path_1)

# %%
df['KOEFISIEN'] = df['SMP'] / df['SMP'].max()

# %%
df.head()
# Out:
#      HARI    JAM  MOTOR  MOBIL  TRUK/BUS  SMP_MTR  SMP_MBL  SMP_TRK  SMP  \
# 0  Monday  00:00    345    192       171       69      192      428  689
# 1  Monday  01:00    259    199       181       52      199      452  704
# 2  Monday  02:00    226    201       182       45      201      455  701
# 3  Monday  03:00    285    195       168       57      195      419  670
# 4  Monday  04:00    552    194       157      110      194      392  697
#
#    SMP_zscore  KOEFISIEN
# 0    0.202864   0.407451
# 1    0.214797   0.416322
# 2    0.212411   0.414548
# 3    0.187749   0.396215
# 4    0.209228   0.412182

# %%
# Daftar kolom yang diinginkan dalam urutan baru
new_column_order = [
    'HARI', 'JAM', 'KOEFISIEN',
    'MOTOR', 'MOBIL', 'TRUK/BUS',
    'SMP_MTR','SMP_MBL','SMP_TRK',
    'SMP'
]
# Menyusun ulang kolom berdasarkan urutan yang diinginkan
df = df.reindex(columns=new_column_order)

# %%
df['SMP'] = np.nan
df['MOTOR'] = np.nan
df['MOBIL'] = np.nan
df['TRUK/BUS'] = np.nan
df['SMP_MTR'] = np.nan
df['SMP_MBL'] = np.nan
df['SMP_TRK'] = np.nan

# %%
df.head()
# Out:
#      HARI    JAM  KOEFISIEN  MOTOR  MOBIL  TRUK/BUS  SMP_MTR  SMP_MBL  \
# 0  Monday  00:00   0.407451    NaN    NaN       NaN      NaN      NaN
# 1  Monday  01:00   0.416322    NaN    NaN       NaN      NaN      NaN
# 2  Monday  02:00   0.414548    NaN    NaN       NaN      NaN      NaN
# 3  Monday  03:00   0.396215    NaN    NaN       NaN      NaN      NaN
# 4  Monday  04:00   0.412182    NaN    NaN       NaN      NaN      NaN
#
#    SMP_TRK  SMP
# 0      NaN  NaN
# 1      NaN  NaN
# 2      NaN  NaN
# 3      NaN  NaN
# 4      NaN  NaN

# %%
df.to_excel('../Data/Preprocessing/Data Balonggandu/2023/5_lhrt_koefisien_balonggandu_2023.xlsx', index=False)
