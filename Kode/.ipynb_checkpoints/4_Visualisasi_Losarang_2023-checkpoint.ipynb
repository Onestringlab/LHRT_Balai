# %%
import os
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
def read_excel(path):
    return pd.read_excel(path)

# %%
path_1 = '../Data/Preprocessing/Data Losarang/2023/3_lhrt_losarang_2023.xlsx'

df = read_excel(path_1)
df.head()
# Out:
#      HARI    JAM         SMP
# 0  Friday  00:00  220.779070
# 1  Friday  01:00  200.196970
# 2  Friday  02:00  174.416667
# 3  Friday  03:00  158.815217
# 4  Friday  04:00  147.046512

# %%
def normalisasi(df, HARI):
    data = df[df['HARI'] == HARI].copy() 
    data.loc[:, 'SMP_zscore'] = (data['SMP'] - data['SMP'].min()) / (data['SMP'].max() - data['SMP'].min())
    return data

# %%
day_names = ['Monday','Tuesday','Wednesday','Thursday','Friday','Saturday','Sunday']
day_names
# Out:
# ['Monday', 'Tuesday', 'Wednesday', 'Thursday', 'Friday', 'Saturday', 'Sunday']

# %%
# List untuk menampung hasil normalisasi
df_list = []

# Iterasi untuk setiap hari dan normalisasi data
for day in day_names:
    df_normalized = normalisasi(df, day)
    df_list.append(df_normalized)

# Menggabungkan kembali hasilnya menjadi satu DataFrame
df_result = pd.concat(df_list)

# %%
df = df_result.copy()
df.to_excel('../Data/Preprocessing/Data Losarang/2023/4_lhrt_normalisasi_losarang_2023.xlsx', index=False)
df.head(48)
# Out:
#         HARI    JAM         SMP  SMP_zscore
# 24    Monday  00:00  127.202128    0.161689
# 25    Monday  01:00  113.335106    0.105864
# 26    Monday  02:00  105.445035    0.074101
# 27    Monday  03:00   96.319149    0.037363
# 28    Monday  04:00   87.038194    0.000000
# 29    Monday  05:00  106.209184    0.077177
# 30    Monday  06:00  194.901667    0.434228
# 31    Monday  07:00  232.600340    0.585992
# 32    Monday  08:00  204.507092    0.472897
# 33    Monday  09:00  193.319149    0.427857
# 34    Monday  10:00  197.914966    0.446359
# 35    Monday  11:00  211.901042    0.502663
# 36    Monday  12:00  213.907986    0.510742
# 37    Monday  13:00  220.119792    0.535749
# 38    Monday  14:00  247.318627    0.645244
# 39    Monday  15:00  261.578333    0.702650
# 40    Monday  16:00  303.312925    0.870661
# 41    Monday  17:00  335.440972    1.000000
# 42    Monday  18:00  267.296099    0.725668
# 43    Monday  19:00  228.865942    0.570959
# 44    Monday  20:00  220.820652    0.538571
# 45    Monday  21:00  245.708333    0.638762
# 46    Monday  22:00  239.967014    0.615649
# 47    Monday  23:00  230.822222    0.578834
# 120  Tuesday  00:00  215.039773    0.310743
# 121  Tuesday  01:00  272.510638    0.619587
# 122  Tuesday  02:00  194.898551    0.202505
# 123  Tuesday  03:00  175.961957    0.100742
# 124  Tuesday  04:00  157.215580    0.000000
# 125  Tuesday  05:00  173.560284    0.087835
# 126  Tuesday  06:00  241.235000    0.451514
# 127  Tuesday  07:00  279.067708    0.654824
# 128  Tuesday  08:00  242.348639    0.457499
# 129  Tuesday  09:00  228.341837    0.382227
# 130  Tuesday  10:00  234.085034    0.413091
# 131  Tuesday  11:00  248.175532    0.488812
# 132  Tuesday  12:00  249.073129    0.493636
# 133  Tuesday  13:00  242.664966    0.459199
# 134  Tuesday  14:00  259.370748    0.548974
# 135  Tuesday  15:00  272.482993    0.619438
# 136  Tuesday  16:00  305.227891    0.795407
# 137  Tuesday  17:00  343.299320    1.000000
# 138  Tuesday  18:00  285.972826    0.691932
# 139  Tuesday  19:00  242.857407    0.460233
# 140  Tuesday  20:00  226.090580    0.370129
# 141  Tuesday  21:00  249.659091    0.496784
# 142  Tuesday  22:00  249.043478    0.493476
# 143  Tuesday  23:00  235.629630    0.421391

# %%
# Urutkan hari secara berurut
urutan_hari = ['Monday', 'Tuesday', 'Wednesday', 'Thursday', 'Friday', 'Saturday', 'Sunday']
df['HARI'] = pd.Categorical(df['HARI'], categories=urutan_hari, ordered=True)

# Iterasi melalui hari dan plot setiap hari
for i, hari in enumerate(urutan_hari):
    fig = plt.subplots(figsize=(12, 8))
    data_harian = df[df['HARI'] == hari]  # Filter data per hari
    sns.lineplot(x=data_harian['JAM'], y=data_harian['SMP'])
    plt.title('Losarang 2023 - ' + hari, fontsize=16)
    plt.xticks(rotation=45)
    plt.grid(True)
    plt.tight_layout()
    plt.savefig('../Data/Visualisasi/Losarang/2023/4_'+str(i+1)+'_'+hari+'_losarang_2023.png')
    plt.show()

# %%
# Urutkan hari secara berurut
urutan_hari = ['Monday', 'Tuesday', 'Wednesday', 'Thursday', 'Friday', 'Saturday', 'Sunday']
df['HARI'] = pd.Categorical(df['HARI'], categories=urutan_hari, ordered=True)

# Iterasi melalui hari dan plot setiap hari
for i, hari in enumerate(urutan_hari):
    fig = plt.subplots(figsize=(12, 8))
    data_harian = df[df['HARI'] == hari]  # Filter data per hari
    sns.lineplot(x=data_harian['JAM'], y=data_harian['SMP_zscore'])
    plt.title('Losarang 2023 (Normalisasi) - ' + hari, fontsize=16)
    plt.xticks(rotation=45)
    plt.tight_layout()
    plt.grid(True)
    plt.savefig('../Data/Visualisasi/Losarang/2023/4_'+str(i+1)+'_'+hari+'_normalisasi_losarang_2023.png')
    plt.show()

# %%
# Ubah 'JAM' menjadi tipe waktu dan 'HARI' menjadi kategori berurut
urutan_hari = ['Monday', 'Tuesday', 'Wednesday', 'Thursday', 'Friday', 'Saturday', 'Sunday']
df['HARI'] = pd.Categorical(df['HARI'], categories=urutan_hari, ordered=True)
# df['JAM'] = pd.to_datetime(df['JAM'], format='%H:%M').dt.time

# Membuat visualisasi menggunakan Seaborn lineplot
plt.figure(figsize=(12, 8))
sns.lineplot(x=df['JAM'].astype(str), y=df['SMP'], hue=df['HARI'])

# Menambahkan label dan judul
plt.title('SMP per Hari dan Jam - Losarang 2023', fontsize=16)
plt.xlabel('Jam', fontsize=12)
plt.ylabel('SMP', fontsize=12)
plt.xticks(rotation=45)
plt.grid(True)

# Menampilkan visualisasi
plt.tight_layout()
plt.savefig('../Data/Visualisasi/Losarang/2023/4_harian_losarang_2023.png')
plt.show()

# %%
# Ubah 'JAM' menjadi tipe waktu dan 'HARI' menjadi kategori berurut
urutan_hari = ['Monday', 'Tuesday', 'Wednesday', 'Thursday', 'Friday', 'Saturday', 'Sunday']
df['HARI'] = pd.Categorical(df['HARI'], categories=urutan_hari, ordered=True)
# df['JAM'] = pd.to_datetime(df['JAM'], format='%H:%M').dt.time

# Membuat visualisasi menggunakan Seaborn lineplot
plt.figure(figsize=(12, 8))
sns.lineplot(x=df['JAM'].astype(str), y=df['SMP_zscore'], hue=df['HARI'])

# Menambahkan label dan judul
plt.title('SMP Normalisasi per Hari dan Jam - Losarang 2023', fontsize=16)
plt.xlabel('Jam', fontsize=12)
plt.ylabel('SMP', fontsize=12)
plt.xticks(rotation=45)
plt.grid(True)

# Menampilkan visualisasi
plt.tight_layout()
plt.savefig('../Data/Visualisasi/Losarang/2023/4_harian_normalisasi_losarang_2023.png')
plt.show()
