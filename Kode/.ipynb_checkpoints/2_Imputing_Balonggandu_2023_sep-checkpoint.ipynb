# %%
import os
import numpy as np
import pandas as pd

# %%
def read_excel(path):
    return pd.read_excel(path)

def imputing_data_row(df,missing):
    df_a = df[df['WAKTU'] == missing['WAKTU'] + pd.Timedelta(minutes=-60)]
    df_b = df[df['WAKTU'] == missing['WAKTU'] + pd.Timedelta(minutes=60)]
    MOTOR = -1
    MOBIL = -1
    TRUK = -1
    if(len(df_a) + len(df_b) == 2):
        result = pd.concat([df_a,df_b])
        MOTOR = round(result['MOTOR'].mean())
        MOBIL = round(result['MOBIL'].mean())
        TRUK = round(result['TRUK/BUS'].mean())
    return MOTOR, MOBIL, TRUK 

def imputing_data(df, HARI, JAM):
    df = df[(df['HARI'] == HARI) & (df['JAM'] == JAM)]
    
    # Menghitung Q1 (kuartil pertama) dan Q3 (kuartil ketiga)
    Q1 = df['SMP'].quantile(0.25)
    Q3 = df['SMP'].quantile(0.75)
    IQR = Q3 - Q1
    
    # Menentukan batas bawah dan batas atas untuk outlier
    lower_bound = Q1 - 1.5 * IQR
    upper_bound = Q3 + 1.5 * IQR
    
    # Menemukan dan menghapus outlier
    df_cleaned = df[(df['SMP'] >= lower_bound) & (df['SMP'] <= upper_bound)]

    df_grouped = df_cleaned[['HARI', 'JAM', 'MOTOR', 'MOBIL','TRUK/BUS']]
    df_grouped = round(df_grouped.groupby(['HARI', 'JAM']).mean()).reset_index()

    return df_grouped

def perhitungan_jumlah_smp(df):
    df['SMP_MOTOR'] = df['MOTOR'] * 0.2
    df['SMP_MBL'] = df['MOBIL']
    df['SMP_TRK'] = df['TRUK/BUS'] * 2.5
    df['SMP'] = round(df['SMP_MTR'] + df['SMP_MBL'] + df['SMP_TRK'])
    df['JUMLAH'] = df['MOTOR'] + df['MOBIL'] + df['TRUK/BUS']
    return df

def menggabungkan_data(df, missing_times):
    # Menggabungkan data hilang dengan DataFrame utama
    df = pd.concat([df, missing_times], ignore_index=True)
    
    # Mengurutkan DataFrame berdasarkan kolom 'Waktu'
    df = df.sort_values(by=['TAHUN','BULAN','TANGGAL','HARI','JAM']).reset_index(drop=True)

    return df

# %%
path_1 = '../Data/Preprocessing/Data Balonggandu/2023/1_input_09 september.xlsx'
path_2 = '../Data/Preprocessing/Data Balonggandu/2023/1_missing_times_09 september.xlsx'

df = read_excel(path_1)
df_missing = read_excel(path_2)

# %%
df.head()
# Out:
#                 WAKTU  TAHUN  BULAN  TANGGAL    HARI    JAM  MOTOR  MOBIL  \
# 0 2024-09-01 00:00:00   2024      9        1  Sunday  00:00     13      9
# 1 2024-09-01 01:00:00   2024      9        1  Sunday  01:00      7      5
# 2 2024-09-01 02:00:00   2024      9        1  Sunday  02:00      6     15
# 3 2024-09-01 03:00:00   2024      9        1  Sunday  03:00      3      8
# 4 2024-09-01 04:00:00   2024      9        1  Sunday  04:00     15     19
#
#    TRUK/BUS  JUMLAH  KOE_MTR  KOE_MBL  KOE_TRK  SMP
# 0         6      28      2.6        9     15.0   27
# 1         7      19      1.4        5     17.5   24
# 2        11      32      1.2       15     27.5   44
# 3         9      20      0.6        8     22.5   31
# 4         8      42      3.0       19     20.0   42

0
#      HARI    JAM  MOTOR  MOBIL  TRUK/BUS
# 0  Friday  10:00   61.0   31.0      11.0
#      HARI    JAM  MOTOR  MOBIL  TRUK/BUS
# 0  Friday  11:00   56.0   21.0      27.0
#      HARI    JAM  MOTOR  MOBIL  TRUK/BUS
# 0  Friday  12:00   42.0   29.0      17.0
#      HARI    JAM  MOTOR  MOBIL  TRUK/BUS
# 0  Friday  13:00   38.0   25.0      18.0
#      HARI    JAM  MOTOR  MOBIL  TRUK/BUS
# 0  Friday  14:00   45.0   32.0      11.0
#      HARI    JAM  MOTOR  MOBIL  TRUK/BUS
# 0  Friday  15:00   46.0   15.0      18.0
#      HARI    JAM  MOTOR  MOBIL  TRUK/BUS
# 0  Friday  16:00   77.0   27.0      21.0
#      HARI    JAM  MOTOR  MOBIL  TRUK/BUS
# 0  Friday  17:00   73.0   17.0      16.0
#      HARI    JAM  MOTOR  MOBIL  TRUK/BUS
# 0  Friday  18:00   71.0   14.0      10.0
#      HARI    JAM  MOTOR  MOBIL  TRUK/BUS
# 0  Friday  19:00   30.0   21.0       4.0
#      HARI    JAM  MOTOR  MOBIL  TRUK/BUS
# 0  Friday  20:00   29.0   15.0       1.0
#      HARI    JAM  MOTOR  MOBIL  TRUK/BUS
# 0  Friday  21:00   24.0    9.0       1.0
#      HARI    JAM  MOTOR  MOBIL  TRUK/BUS
# 0  Friday  22:00   16.0   10.0       4.0
#      HARI    JAM  MOTOR  MOBIL  TRUK/BUS
# 0  Friday  23:00    9.0   13.0       5.0
#        HARI    JAM  MOTOR  MOBIL  TRUK/BUS
# 0  Saturday  00:00   13.0   11.0       8.0
#        HARI    JAM  MOTOR  MOBIL  TRUK/BUS
# 0  Saturday  01:00   14.0    8.0       8.0
#        HARI    JAM  MOTOR  MOBIL  TRUK/BUS
# 0  Saturday  02:00   23.0    7.0       5.0
#        HARI    JAM  MOTOR  MOBIL  TRUK/BUS
# 0  Saturday  03:00   27.0    6.0       7.0
#        HARI    JAM  MOTOR  MOBIL  TRUK/BUS
# 0  Saturday  04:00   24.0   20.0      10.0
#        HARI    JAM  MOTOR  MOBIL  TRUK/BUS
# 0  Saturday  05:00   73.0    8.0      14.0
#        HARI    JAM  MOTOR  MOBIL  TRUK/BUS
# 0  Saturday  06:00  186.0   21.0      17.0
#        HARI    JAM  MOTOR  MOBIL  TRUK/BUS
# 0  Saturday  07:00   59.0   18.0      14.0
#        HARI    JAM  MOTOR  MOBIL  TRUK/BUS
# 0  Saturday  08:00   41.0   20.0      18.0
#        HARI    JAM  MOTOR  MOBIL  TRUK/BUS
# 0  Saturday  09:00   72.0   27.0      12.0
#        HARI    JAM  MOTOR  MOBIL  TRUK/BUS
# 0  Saturday  10:00   51.0    9.0      11.0
#        HARI    JAM  MOTOR  MOBIL  TRUK/BUS
# 0  Saturday  11:00   42.0   23.0      10.0
#        HARI    JAM  MOTOR  MOBIL  TRUK/BUS
# 0  Saturday  12:00   32.0   19.0      13.0
#        HARI    JAM  MOTOR  MOBIL  TRUK/BUS
# 0  Saturday  13:00   54.0   15.0       7.0
#        HARI    JAM  MOTOR  MOBIL  TRUK/BUS
# 0  Saturday  14:00   86.0   26.0       7.0
#        HARI    JAM  MOTOR  MOBIL  TRUK/BUS
# 0  Saturday  15:00  128.0   32.0      17.0
#        HARI    JAM  MOTOR  MOBIL  TRUK/BUS
# 0  Saturday  16:00   92.0   23.0      13.0
#        HARI    JAM  MOTOR  MOBIL  TRUK/BUS
# 0  Saturday  17:00   62.0   16.0       7.0
#        HARI    JAM  MOTOR  MOBIL  TRUK/BUS
# 0  Saturday  18:00   79.0   23.0       4.0
#        HARI    JAM  MOTOR  MOBIL  TRUK/BUS
# 0  Saturday  19:00   58.0   12.0       8.0
#        HARI    JAM  MOTOR  MOBIL  TRUK/BUS
# 0  Saturday  20:00   55.0   14.0       2.0
#        HARI    JAM  MOTOR  MOBIL  TRUK/BUS
# 0  Saturday  21:00   35.0    8.0       4.0
#        HARI    JAM  MOTOR  MOBIL  TRUK/BUS
# 0  Saturday  22:00   29.0    6.0       4.0
#        HARI    JAM  MOTOR  MOBIL  TRUK/BUS
# 0  Saturday  23:00   14.0   11.0       1.0
#      HARI    JAM  MOTOR  MOBIL  TRUK/BUS
# 0  Sunday  00:00   13.0   10.0       7.0
#      HARI    JAM  MOTOR  MOBIL  TRUK/BUS
# 0  Sunday  01:00   10.0    6.0       8.0
#      HARI    JAM  MOTOR  MOBIL  TRUK/BUS
# 0  Sunday  02:00   14.0   11.0       8.0
#      HARI    JAM  MOTOR  MOBIL  TRUK/BUS
# 0  Sunday  03:00   15.0    7.0       8.0
#      HARI    JAM  MOTOR  MOBIL  TRUK/BUS
# 0  Sunday  04:00   20.0   20.0       9.0
#      HARI    JAM  MOTOR  MOBIL  TRUK/BUS
# 0  Sunday  05:00   74.0    9.0      12.0
#      HARI    JAM  MOTOR  MOBIL  TRUK/BUS
# 0  Sunday  06:00  152.0   20.0      16.0
#      HARI    JAM  MOTOR  MOBIL  TRUK/BUS
# 0  Sunday  07:00   68.0   21.0      14.0
#      HARI    JAM  MOTOR  MOBIL  TRUK/BUS
# 0  Sunday  08:00   46.0   23.0      14.0
#      HARI    JAM  MOTOR  MOBIL  TRUK/BUS
# 0  Sunday  09:00   58.0   24.0      10.0
#      HARI    JAM  MOTOR  MOBIL  TRUK/BUS
# 0  Sunday  10:00   52.0   19.0      16.0
#      HARI    JAM  MOTOR  MOBIL  TRUK/BUS
# 0  Sunday  11:00   34.0   18.0      16.0
#      HARI    JAM  MOTOR  MOBIL  TRUK/BUS
# 0  Sunday  12:00   33.0   20.0      13.0
#      HARI    JAM  MOTOR  MOBIL  TRUK/BUS
# 0  Sunday  13:00   57.0   22.0      10.0
#      HARI    JAM  MOTOR  MOBIL  TRUK/BUS
# 0  Sunday  14:00   74.0   34.0      14.0
#      HARI    JAM  MOTOR  MOBIL  TRUK/BUS
# 0  Sunday  15:00   96.0   26.0      16.0
#      HARI    JAM  MOTOR  MOBIL  TRUK/BUS
# 0  Sunday  16:00   84.0   26.0      16.0
#      HARI    JAM  MOTOR  MOBIL  TRUK/BUS
# 0  Sunday  17:00   66.0   22.0      10.0
#      HARI    JAM  MOTOR  MOBIL  TRUK/BUS
# 0  Sunday  18:00   70.0   24.0       5.0
#      HARI    JAM  MOTOR  MOBIL  TRUK/BUS
# 0  Sunday  19:00   46.0   14.0       5.0
#      HARI    JAM  MOTOR  MOBIL  TRUK/BUS
# 0  Sunday  20:00   55.0   14.0       2.0
#      HARI    JAM  MOTOR  MOBIL  TRUK/BUS
# 0  Sunday  21:00   36.0   10.0       6.0
#      HARI    JAM  MOTOR  MOBIL  TRUK/BUS
# 0  Sunday  22:00   22.0    8.0       5.0
#      HARI    JAM  MOTOR  MOBIL  TRUK/BUS
# 0  Sunday  23:00   13.0    7.0       3.0
#      HARI    JAM  MOTOR  MOBIL  TRUK/BUS
# 0  Monday  00:00   10.0   13.0       8.0
#      HARI    JAM  MOTOR  MOBIL  TRUK/BUS
# 0  Monday  01:00    6.0   11.0       6.0
#      HARI    JAM  MOTOR  MOBIL  TRUK/BUS
# 0  Monday  02:00    6.0   11.0       6.0
#      HARI    JAM  MOTOR  MOBIL  TRUK/BUS
# 0  Monday  03:00    7.0    6.0       6.0
#      HARI    JAM  MOTOR  MOBIL  TRUK/BUS
# 0  Monday  04:00   20.0   11.0       9.0
#      HARI    JAM  MOTOR  MOBIL  TRUK/BUS
# 0  Monday  05:00   70.0    8.0      11.0
#      HARI    JAM  MOTOR  MOBIL  TRUK/BUS
# 0  Monday  06:00  114.0    8.0       9.0
#      HARI    JAM  MOTOR  MOBIL  TRUK/BUS
# 0  Monday  07:00   72.0   22.0       6.0
#      HARI    JAM  MOTOR  MOBIL  TRUK/BUS
# 0  Monday  08:00   40.0   17.0       7.0
#      HARI    JAM  MOTOR  MOBIL  TRUK/BUS
# 0  Monday  09:00   67.0   26.0       6.0
#      HARI    JAM  MOTOR  MOBIL  TRUK/BUS
# 0  Monday  10:00   82.0   29.0      30.0
#      HARI    JAM  MOTOR  MOBIL  TRUK/BUS
# 0  Monday  11:00   26.0   19.0      13.0
#      HARI    JAM  MOTOR  MOBIL  TRUK/BUS
# 0  Monday  12:00   23.0   12.0       5.0
#      HARI    JAM  MOTOR  MOBIL  TRUK/BUS
# 0  Monday  13:00   74.0   31.0      11.0
#      HARI    JAM  MOTOR  MOBIL  TRUK/BUS
# 0  Monday  14:00   97.0   30.0      21.0
#      HARI    JAM  MOTOR  MOBIL  TRUK/BUS
# 0  Monday  15:00   70.0   29.0      16.0
#      HARI    JAM  MOTOR  MOBIL  TRUK/BUS
# 0  Monday  16:00   74.0   19.0       9.0
#      HARI    JAM  MOTOR  MOBIL  TRUK/BUS
# 0  Monday  17:00   95.0   30.0      18.0
#      HARI    JAM  MOTOR  MOBIL  TRUK/BUS
# 0  Monday  18:00   56.0   11.0       7.0
#      HARI    JAM  MOTOR  MOBIL  TRUK/BUS
# 0  Monday  19:00   53.0   13.0       1.0
#      HARI    JAM  MOTOR  MOBIL  TRUK/BUS
# 0  Monday  20:00   35.0   12.0       5.0
#      HARI    JAM  MOTOR  MOBIL  TRUK/BUS
# 0  Monday  21:00   30.0   13.0       3.0
#      HARI    JAM  MOTOR  MOBIL  TRUK/BUS
# 0  Monday  22:00   32.0    7.0       6.0
#      HARI    JAM  MOTOR  MOBIL  TRUK/BUS
# 0  Monday  23:00   12.0    7.0       1.0

# %%
imputasi
# Out:
#      HARI    JAM  MOTOR  MOBIL  TRUK/BUS
# 0  Monday  23:00   12.0    7.0       1.0

# %%
# Iterasi setiap baris dan mengisi nilai yang hilang
# for i, missing in df_missing.iterrows():
#     MOTOR, MOBIL, TRUK = imputing_data_row(df, missing)
#     if (MOTOR != -1) & (np.isnan(missing['MOTOR'])):
#         df_missing.at[i, 'MOTOR'] = MOTOR
#         df_missing.at[i, 'MOBIL'] = MOBIL
#         df_missing.at[i, 'TRUK/BUS'] = TRUK

# %%
# Iterasi setiap baris dan mengisi nilai yang hilang
for i, missing in df_missing.iterrows():
    imputasi = imputing_data(df, missing['HARI'], missing['JAM'])
    if not imputasi.empty:
        df_missing.at[i, 'MOTOR'] = imputasi['MOTOR'].values[0]
        df_missing.at[i, 'MOBIL'] = imputasi['MOBIL'].values[0]
        df_missing.at[i, 'TRUK/BUS'] = imputasi['TRUK/BUS'].values[0]

# %%
df_missing = perhitungan_jumlah_smp(df_missing)

# %%
df_missing.to_excel('../Data/Preprocessing/Data Balonggandu/2023/2_missing_times_09 september.xlsx', index=False)

# %%
df_missing.head()
# Out:
#                 WAKTU  TAHUN  BULAN  TANGGAL    HARI    JAM  MOTOR  MOBIL  \
# 0 2024-09-09 00:00:00   2024      9        9  Monday  00:00   10.0   13.0
# 1 2024-09-09 01:00:00   2024      9        9  Monday  01:00    6.0   11.0
# 2 2024-09-09 02:00:00   2024      9        9  Monday  02:00    6.0   11.0
# 3 2024-09-09 03:00:00   2024      9        9  Monday  03:00    7.0    6.0
# 4 2024-09-09 04:00:00   2024      9        9  Monday  04:00   20.0   11.0
#
#    TRUK/BUS  JUMLAH  KOE_MTR  KOE_MBL  KOE_TRK   SMP
# 0       8.0    31.0      2.0     13.0     20.0  35.0
# 1       6.0    23.0      1.2     11.0     15.0  27.0
# 2       6.0    23.0      1.2     11.0     15.0  27.0
# 3       6.0    19.0      1.4      6.0     15.0  22.0
# 4       9.0    40.0      4.0     11.0     22.5  38.0

# %%
df_missing.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 514 entries, 0 to 513
# Data columns (total 14 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   WAKTU     514 non-null    datetime64[ns]
#  1   TAHUN     514 non-null    int64
#  2   BULAN     514 non-null    int64
#  3   TANGGAL   514 non-null    int64
#  4   HARI      514 non-null    object
#  5   JAM       514 non-null    object
#  6   MOTOR     514 non-null    float64
#  7   MOBIL     514 non-null    float64
#  8   TRUK/BUS  514 non-null    float64
#  9   JUMLAH    514 non-null    float64
#  10  KOE_MTR   514 non-null    float64
#  11  KOE_MBL   514 non-null    float64
#  12  KOE_TRK   514 non-null    float64
#  13  SMP       514 non-null    float64
# dtypes: datetime64[ns](1), float64(8), int64(3), object(2)
# memory usage: 56.3+ KB

# %%
df_compiled = menggabungkan_data(df, df_missing)
df_compiled.head()
# Out:
#                 WAKTU  TAHUN  BULAN  TANGGAL    HARI    JAM  MOTOR  MOBIL  \
# 0 2024-09-01 00:00:00   2024      9        1  Sunday  00:00   13.0    9.0
# 1 2024-09-01 01:00:00   2024      9        1  Sunday  01:00    7.0    5.0
# 2 2024-09-01 02:00:00   2024      9        1  Sunday  02:00    6.0   15.0
# 3 2024-09-01 03:00:00   2024      9        1  Sunday  03:00    3.0    8.0
# 4 2024-09-01 04:00:00   2024      9        1  Sunday  04:00   15.0   19.0
#
#    TRUK/BUS  JUMLAH  KOE_MTR  KOE_MBL  KOE_TRK   SMP
# 0       6.0    28.0      2.6      9.0     15.0  27.0
# 1       7.0    19.0      1.4      5.0     17.5  24.0
# 2      11.0    32.0      1.2     15.0     27.5  44.0
# 3       9.0    20.0      0.6      8.0     22.5  31.0
# 4       8.0    42.0      3.0     19.0     20.0  42.0

# %%
df_compiled.to_excel('../Data/Preprocessing/Data Balonggandu/2023/2_input_09 september.xlsx', index=False)
