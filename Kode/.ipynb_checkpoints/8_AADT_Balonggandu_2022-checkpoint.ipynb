# %%
import os
import calendar
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
def read_excel(path):
    return pd.read_excel(path)
    
def days_in_month(year, month):
    return calendar.monthrange(year, month)[1]

# %%
file = 'balonggandu_2022'
path = 'Data Balonggandu/2022'
path_1 = '../Data/Preprocessing/' + path + '/2_input_' + file + '.xlsx'

df = read_excel(path_1)
df.head()
# Out:
#                 WAKTU  TAHUN  BULAN  PEKAN  TANGGAL      HARI    JAM  MOTOR  \
# 0 2022-01-01 00:00:00   2022      1      1        1  Saturday  00:00     58
# 1 2022-01-01 00:15:00   2022      1      1        1  Saturday  00:15     54
# 2 2022-01-01 00:30:00   2022      1      1        1  Saturday  00:30     37
# 3 2022-01-01 00:45:00   2022      1      1        1  Saturday  00:45     39
# 4 2022-01-01 01:00:00   2022      1      1        1  Saturday  01:00     35
#
#    MOBIL  TRUK/BUS  JUMLAH  SMP_MTR  SMP_MBL  SMP_TRK  SMP
# 0     40        36     134     46.4       40     90.0  176
# 1     43        37     134     43.2       43     92.5  179
# 2     41        35     113     29.6       41     87.5  158
# 3     42        28     109     31.2       42     70.0  143
# 4     45        41     121     28.0       45    102.5  176

# %%
df['SMP'] = df['SMP_MTR']+df['SMP_MBL']+df['SMP_TRK']

# %%
df.head()
# Out:
#                 WAKTU  TAHUN  BULAN  PEKAN  TANGGAL      HARI    JAM  MOTOR  \
# 0 2022-01-01 00:00:00   2022      1      1        1  Saturday  00:00     58
# 1 2022-01-01 00:15:00   2022      1      1        1  Saturday  00:15     54
# 2 2022-01-01 00:30:00   2022      1      1        1  Saturday  00:30     37
# 3 2022-01-01 00:45:00   2022      1      1        1  Saturday  00:45     39
# 4 2022-01-01 01:00:00   2022      1      1        1  Saturday  01:00     35
#
#    MOBIL  TRUK/BUS  JUMLAH  SMP_MTR  SMP_MBL  SMP_TRK    SMP
# 0     40        36     134     46.4       40     90.0  176.4
# 1     43        37     134     43.2       43     92.5  178.7
# 2     41        35     113     29.6       41     87.5  158.1
# 3     42        28     109     31.2       42     70.0  143.2
# 4     45        41     121     28.0       45    102.5  175.5

# %%
df_smp = df[['WAKTU','TAHUN', 'BULAN', 'TANGGAL', 'HARI','JAM','MOTOR','MOBIL','TRUK/BUS',
                              'SMP_MTR','SMP_MBL','SMP_TRK','SMP']]

# %%
df_smp.head()
# Out:
#                 WAKTU  TAHUN  BULAN  TANGGAL      HARI    JAM  MOTOR  MOBIL  \
# 0 2022-01-01 00:00:00   2022      1        1  Saturday  00:00     58     40
# 1 2022-01-01 00:15:00   2022      1        1  Saturday  00:15     54     43
# 2 2022-01-01 00:30:00   2022      1        1  Saturday  00:30     37     41
# 3 2022-01-01 00:45:00   2022      1        1  Saturday  00:45     39     42
# 4 2022-01-01 01:00:00   2022      1        1  Saturday  01:00     35     45
#
#    TRUK/BUS  SMP_MTR  SMP_MBL  SMP_TRK    SMP
# 0        36     46.4       40     90.0  176.4
# 1        37     43.2       43     92.5  178.7
# 2        35     29.6       41     87.5  158.1
# 3        28     31.2       42     70.0  143.2
# 4        41     28.0       45    102.5  175.5

# %%
len(df_smp)
# Out:
# 35040

# %% [markdown]
# # Group SMP Per Jam

# %%
# Round down the WAKTU column to the nearest hour
df_smp_jam = df_smp.copy()
df_smp_jam['JAM'] = df_smp['WAKTU'].dt.floor('H')

# Drop the original WAKTU column if it's not needed anymore
df_smp_jam = df_smp_jam.drop(columns=['WAKTU'])

# Format the 'JAM' column to show only hour and minute
df_smp_jam['JAM'] = df_smp_jam['JAM'].dt.strftime('%H:%M')

# Group by the rounded-down hour and sum the SMP column
df_smp_jam = df_smp_jam.groupby(['TAHUN', 'BULAN', 'TANGGAL', 'HARI', 'JAM'], as_index=False).sum()

# %%
df_smp_jam.head()
# Out:
#    TAHUN  BULAN  TANGGAL      HARI    JAM  MOTOR  MOBIL  TRUK/BUS  SMP_MTR  \
# 0   2022      1        1  Saturday  00:00    188    166       136    150.4
# 1   2022      1        1  Saturday  01:00    129    176       141    103.2
# 2   2022      1        1  Saturday  02:00     88    157       128     70.4
# 3   2022      1        1  Saturday  03:00    119    156       126     95.2
# 4   2022      1        1  Saturday  04:00    201    142       109    160.8
#
#    SMP_MBL  SMP_TRK    SMP
# 0      166    340.0  656.4
# 1      176    352.5  631.7
# 2      157    320.0  547.4
# 3      156    315.0  566.2
# 4      142    272.5  575.3

# %%
len(df_smp_jam)
# Out:
# 8760

# %%
df_smp_jam.to_excel('../Data/Preprocessing/' + path + '/8_smp_jam_' + file + '.xlsx', index=False)

# %% [markdown]
# # Group SMP Per Hari

# %%
df_smp_hari = df_smp_jam.copy()

# %%
df_smp_hari = df_smp_hari.drop(columns=['JAM'])

# %%
df_smp_hari = df_smp_hari.groupby(['TAHUN', 'BULAN', 'TANGGAL', 'HARI'], as_index=False).sum()

# %%
df_smp_hari['RT_JAM'] = df_smp_hari['SMP']/24

# %%
df_smp_hari.head()
# Out:
#    TAHUN  BULAN  TANGGAL       HARI  MOTOR  MOBIL  TRUK/BUS  SMP_MTR  SMP_MBL  \
# 0   2022      1        1   Saturday  20715   7381      4637  16572.0     7381
# 1   2022      1        2     Sunday  23327   7957      3438  18661.6     7957
# 2   2022      1        3     Monday  28192   7118      4984  22553.6     7118
# 3   2022      1        4    Tuesday  24187   6715      5136  19349.6     6715
# 4   2022      1        5  Wednesday  23481   6703      5427  18784.8     6703
#
#    SMP_TRK      SMP       RT_JAM
# 0  11592.5  35545.5  1481.062500
# 1   8595.0  35213.6  1467.233333
# 2  12460.0  42131.6  1755.483333
# 3  12840.0  38904.6  1621.025000
# 4  13567.5  39055.3  1627.304167

# %%
len(df_smp_hari)
# Out:
# 365

# %%
df_smp_hari.to_excel('../Data/Preprocessing/' + path + '/8_smp_hari_' + file + '.xlsx', index=False)

# %% [markdown]
# # Group SMP Per Bulan

# %%
df_smp_bln = df_smp_hari.copy()

# %%
df_smp_bln = df_smp_bln.drop(columns=['TANGGAL','HARI','RT_JAM'])

# %%
df_smp_bln.head()
# Out:
#    TAHUN  BULAN  MOTOR  MOBIL  TRUK/BUS  SMP_MTR  SMP_MBL  SMP_TRK      SMP
# 0   2022      1  20715   7381      4637  16572.0     7381  11592.5  35545.5
# 1   2022      1  23327   7957      3438  18661.6     7957   8595.0  35213.6
# 2   2022      1  28192   7118      4984  22553.6     7118  12460.0  42131.6
# 3   2022      1  24187   6715      5136  19349.6     6715  12840.0  38904.6
# 4   2022      1  23481   6703      5427  18784.8     6703  13567.5  39055.3

# %%
df_smp_bln = df_smp_bln.groupby(['TAHUN', 'BULAN'], as_index=False).sum()
df_smp_bln['LHR_BLN'] = df_smp_bln.apply(lambda row: row['SMP'] / days_in_month(int(row['TAHUN']), int(row['BULAN'])), axis=1)

# %%
df_smp_bln.head()
# Out:
#    TAHUN  BULAN   MOTOR   MOBIL  TRUK/BUS   SMP_MTR  SMP_MBL   SMP_TRK  \
# 0   2022      1  734170  220664    152711  587336.0   220664  381777.5
# 1   2022      2  634628  188312    140864  507702.4   188312  352160.0
# 2   2022      3  685522  203653    155625  548417.6   203653  389062.5
# 3   2022      4  638800  201063    148121  511040.0   201063  370302.5
# 4   2022      5  710204  215996    154383  568163.2   215996  385957.5
#
#          SMP       LHR_BLN
# 0  1189777.5  38379.919355
# 1  1048174.4  37434.800000
# 2  1141133.1  36810.745161
# 3  1082405.5  36080.183333
# 4  1170116.7  37745.700000

# %%
len(df_smp_bln)
# Out:
# 12

# %%
df_smp_bln.to_excel('../Data/Preprocessing/' + path + '/8_smp_bulan_' + file + '.xlsx', index=False)

# %% [markdown]
# # Menghitung LHRT (AADT)

# %%
# Menghitung AADT
aadts = {}
for month in df_smp_hari['BULAN'].unique():
    monthly_data = df_smp_hari[df_smp_hari['BULAN'] == month]
    weekly_averages = []
    for day in monthly_data['HARI'].unique():
        daily_data = monthly_data[monthly_data['HARI'] == day]
        daily_average = daily_data['SMP'].mean()
        weekly_averages.append(daily_average)
    monthly_average = np.mean(weekly_averages)
    aadts[month] = monthly_average

# Mengubah dictionary menjadi DataFrame
aadts_df = pd.DataFrame(list(aadts.items()), columns=['BULAN', 'LHR_BLN'])

# %%
aadts_df.head(12)
# Out:
#     BULAN       LHR_BLN
# 0       1  38460.242857
# 1       2  37434.800000
# 2       3  36867.814286
# 3       4  36163.771429
# 4       5  37701.328571
# 5       6  35477.600000
# 6       7  35517.928571
# 7       8  32456.257143
# 8       9  35781.685714
# 9      10  35932.071429
# 10     11  37904.371429
# 11     12  35619.800000

# %%
aadt = aadts_df['LHR_BLN'].mean()
print(f"Estimated AADT is {aadt}")
# Out:
# Estimated AADT is 36276.472619047614

# %%
aadt_simple = df_smp_hari['SMP'].mean()
print(f"Estimated AADT is {aadt_simple}")
# Out:
# Estimated AADT is 36238.10547945205

# %%
aadts_df.to_excel('../Data/Preprocessing/' + path + '/8_aadt_bulan_' + file + '.xlsx', index=False)

# %%
aadts_df
# Out:
#     BULAN       LHR_BLN
# 0       1  38460.242857
# 1       2  37434.800000
# 2       3  36867.814286
# 3       4  36163.771429
# 4       5  37701.328571
# 5       6  35477.600000
# 6       7  35517.928571
# 7       8  32456.257143
# 8       9  35781.685714
# 9      10  35932.071429
# 10     11  37904.371429
# 11     12  35619.800000

# %% [markdown]
# # Menghitung Faktor K

# %%
df_k = df_smp_jam.copy()
df_k = df_k.sort_values('SMP', ascending=False)
df_k = df_k.reset_index(drop=True)

# %%
df_k.head()
# Out:
#    TAHUN  BULAN  TANGGAL    HARI    JAM  MOTOR  MOBIL  TRUK/BUS  SMP_MTR  \
# 0   2022     11       28  Monday  06:00   2930    334       376   2344.0
# 1   2022     11       21  Monday  06:00   2930    334       376   2344.0
# 2   2022     11        7  Monday  06:00   2930    334       376   2344.0
# 3   2022     11       14  Monday  06:00   2930    334       376   2344.0
# 4   2022      3        7  Monday  06:00   3004    315       354   2403.2
#
#    SMP_MBL  SMP_TRK     SMP
# 0      334    940.0  3618.0
# 1      334    940.0  3618.0
# 2      334    940.0  3618.0
# 3      334    940.0  3618.0
# 4      315    885.0  3603.2

# %%
# Assuming df_k_200 is already sorted by 'SMP'
fig, ax = plt.subplots(figsize=(10, 6))

# Plot the entire SMP data
ax.plot(df_k.index, df_k['SMP'], linestyle='-', color='blue', label='SMP')

# Highlight the 30th, 50th, and 100th highest volumes
k30_point = ax.plot(29, df_k.iloc[29]['SMP'], 'ro', label=f'SMP-30: {df_k.iloc[29]["SMP"]:.2f}')
k50_point = ax.plot(49, df_k.iloc[49]['SMP'], 'go', label=f'SMP-50: {df_k.iloc[49]["SMP"]:.2f}')
k100_point = ax.plot(99, df_k.iloc[99]['SMP'], 'yo', label=f'SMP-100: {df_k.iloc[99]["SMP"]:.2f}')

# Setting plot titles and labels
ax.set_title('SMP per Hour Indexed')
ax.set_xlabel('Index')
ax.set_ylabel('SMP')
ax.grid(True)

# Adding legend
ax.legend()

# Show the plot
plt.xticks(rotation=45)
plt.tight_layout()
plt.savefig('../Data/Visualisasi/Balonggandu/2022/8_smp_hour_sort_' + file + '.png')
plt.show()

# %%
df_k_200 = df_k.head(200)

# %%
# Assuming df_k_200 is already sorted by 'SMP'
fig, ax = plt.subplots(figsize=(10, 6))

# Plot the entire SMP data
ax.plot(df_k_200.index, df_k_200['SMP'], linestyle='-', color='blue', label='SMP')

# Highlight the 30th, 50th, and 100th highest volumes
k30_point = ax.plot(29, df_k_200.iloc[29]['SMP'], 'ro', label=f'SMP-30: {df_k_200.iloc[29]["SMP"]:.2f}')
k50_point = ax.plot(49, df_k_200.iloc[49]['SMP'], 'go', label=f'SMP-50: {df_k_200.iloc[49]["SMP"]:.2f}')
k100_point = ax.plot(99, df_k_200.iloc[99]['SMP'], 'yo', label=f'SMP-100: {df_k_200.iloc[99]["SMP"]:.2f}')

# Setting plot titles and labels
ax.set_title('SMP per Hour Indexed')
ax.set_xlabel('Index')
ax.set_ylabel('SMP')
ax.grid(True)

# Adding legend
ax.legend()

# Show the plot
plt.xticks(rotation=45)
plt.tight_layout()
plt.savefig('../Data/Visualisasi/Balonggandu/2022/8_smp_hour_sort_200_' + file + '.png')
plt.show()

# %%
faktor_k = {}

# Assuming df_k is sorted by 'SMP' in descending order and AADT is predefined
K_30 = (df_k.loc[29, 'SMP'] / aadt) * 100  # Accessing the 30th highest value
K_50 = (df_k.loc[49, 'SMP'] / aadt) * 100  # Accessing the 50th highest value
K_100 = (df_k.loc[99, 'SMP'] / aadt) * 100  # Accessing the 100th highest value

faktor_k['K-30'] = f"{K_30:.2f}%"
faktor_k['K-50'] = f"{K_50:.2f}%"
faktor_k['K-100'] = f"{K_100:.2f}%"

# Mengubah dictionary menjadi DataFrame
faktor_k_df = pd.DataFrame(list(faktor_k.items()), columns=['K', 'Factor'])

# %%
faktor_k_df.head()
# Out:
#        K Factor
# 0   K-30  9.49%
# 1   K-50  9.24%
# 2  K-100  8.66%

# %%
faktor_k_df.to_excel('../Data/Preprocessing/' + path + '/8_faktor_k_' + file + '.xlsx', index=False)

# %% [markdown]
# # Menghitung Proporsi Harian Terhadap Tahunan

# %%
df_pro_hari_thn = df_smp_hari.copy()
df_pro_hari_thn['PRO_HARI_THN'] = df_pro_hari_thn['SMP']/aadt
df_pro_hari_thn = df_pro_hari_thn[['TAHUN','BULAN','TANGGAL','SMP','PRO_HARI_THN']]

# %%
df_pro_hari_thn.head()
# Out:
#    TAHUN  BULAN  TANGGAL      SMP  PRO_HARI_THN
# 0   2022      1        1  35545.5      0.979850
# 1   2022      1        2  35213.6      0.970701
# 2   2022      1        3  42131.6      1.161403
# 3   2022      1        4  38904.6      1.072447
# 4   2022      1        5  39055.3      1.076601

# %%
df_pro_hari_thn.to_excel('../Data/Preprocessing/' + path + '/8_pro_hari_thn_' + file + '.xlsx', index=False)

# %% [markdown]
# # Menghitung Proporsi Harian Terhadap Bulanan

# %%
data_gabungan = pd.merge(aadts_df[['BULAN','LHR_BLN']], df_smp_hari, on=['BULAN'])

# %%
data_gabungan = data_gabungan[['TAHUN', 'BULAN','TANGGAL','HARI','SMP','LHR_BLN']]

# %%
data_gabungan['PRO_HARI_BLN'] = data_gabungan['SMP']/aadt

# %%
data_gabungan.head()
# Out:
#    TAHUN  BULAN  TANGGAL       HARI      SMP       LHR_BLN  PRO_HARI_BLN
# 0   2022      1        1   Saturday  35545.5  38460.242857      0.979850
# 1   2022      1        2     Sunday  35213.6  38460.242857      0.970701
# 2   2022      1        3     Monday  42131.6  38460.242857      1.161403
# 3   2022      1        4    Tuesday  38904.6  38460.242857      1.072447
# 4   2022      1        5  Wednesday  39055.3  38460.242857      1.076601

# %%
data_gabungan.to_excel('../Data/Preprocessing/' + path + '/8_pro_hari_bln_' + file + '.xlsx', index=False)

# %% [markdown]
# # Menghitung Proporsi Bulanan Terhadap Tahunan

# %%
df_pro_bul_thn = df_smp_bln.copy()
df_pro_bul_thn['PRO_BLN_THN'] = df_smp_bln['LHR_BLN']/aadt
df_pro_bul_thn = df_pro_bul_thn[['TAHUN','BULAN','LHR_BLN','PRO_BLN_THN']]

# %%
df_pro_bul_thn.head(12)
# Out:
#     TAHUN  BULAN       LHR_BLN  PRO_BLN_THN
# 0    2022      1  38379.919355     1.057984
# 1    2022      2  37434.800000     1.031931
# 2    2022      3  36810.745161     1.014728
# 3    2022      4  36080.183333     0.994589
# 4    2022      5  37745.700000     1.040501
# 5    2022      6  35449.496667     0.977204
# 6    2022      7  35384.390323     0.975409
# 7    2022      8  32581.148387     0.898134
# 8    2022      9  35769.436667     0.986023
# 9    2022     10  35894.977419     0.989484
# 10   2022     11  37882.730000     1.044278
# 11   2022     12  35566.948387     0.980441

# %%
df_pro_bul_thn.to_excel('../Data/Preprocessing/' + path + '/8_pro_bln_thn_' + file + '.xlsx', index=False)
