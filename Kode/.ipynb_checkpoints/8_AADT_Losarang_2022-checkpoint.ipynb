# %%
import os
import calendar
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
def read_excel(path):
    return pd.read_excel(path)
    
def days_in_month(year, month):
    return calendar.monthrange(year, month)[1]

# %%
file = 'losarang_2022'
path = 'Data Losarang/2022'
path_1 = '../Data/Preprocessing/' + path + '/2_input_' + file + '.xlsx'

df = read_excel(path_1)
df.head()
# Out:
#                 WAKTU  TAHUN  BULAN  PEKAN  TANGGAL      HARI    JAM  MOTOR  \
# 0 2022-01-01 00:00:00   2022      1      1        1  Saturday  00:00    185
# 1 2022-01-01 00:15:00   2022      1      1        1  Saturday  00:15    195
# 2 2022-01-01 00:30:00   2022      1      1        1  Saturday  00:30    194
# 3 2022-01-01 00:45:00   2022      1      1        1  Saturday  00:45    162
# 4 2022-01-01 01:00:00   2022      1      1        1  Saturday  01:00    125
#
#    MOBIL  TRUK/BUS  JUMLAH  SMP_MTR  SMP_MBL  SMP_TRK  SMP
# 0     39        24     248    148.0       39     60.0  247
# 1     64        35     294    156.0       64     87.5  308
# 2     49        17     260    155.2       49     42.5  247
# 3     43        21     226    129.6       43     52.5  225
# 4     58        18     201    100.0       58     45.0  203

# %%
df['SMP'] = df['SMP_MTR']+df['SMP_MBL']+df['SMP_TRK']

# %%
df.head()
# Out:
#                 WAKTU  TAHUN  BULAN  PEKAN  TANGGAL      HARI    JAM  MOTOR  \
# 0 2022-01-01 00:00:00   2022      1      1        1  Saturday  00:00    185
# 1 2022-01-01 00:15:00   2022      1      1        1  Saturday  00:15    195
# 2 2022-01-01 00:30:00   2022      1      1        1  Saturday  00:30    194
# 3 2022-01-01 00:45:00   2022      1      1        1  Saturday  00:45    162
# 4 2022-01-01 01:00:00   2022      1      1        1  Saturday  01:00    125
#
#    MOBIL  TRUK/BUS  JUMLAH  SMP_MTR  SMP_MBL  SMP_TRK    SMP
# 0     39        24     248    148.0       39     60.0  247.0
# 1     64        35     294    156.0       64     87.5  307.5
# 2     49        17     260    155.2       49     42.5  246.7
# 3     43        21     226    129.6       43     52.5  225.1
# 4     58        18     201    100.0       58     45.0  203.0

# %%
df_smp = df[['WAKTU','TAHUN', 'BULAN', 'TANGGAL', 'HARI','JAM','MOTOR','MOBIL','TRUK/BUS',
                              'SMP_MTR','SMP_MBL','SMP_TRK','SMP']]

# %%
df_smp.head()
# Out:
#                 WAKTU  TAHUN  BULAN  TANGGAL      HARI    JAM  MOTOR  MOBIL  \
# 0 2022-01-01 00:00:00   2022      1        1  Saturday  00:00    185     39
# 1 2022-01-01 00:15:00   2022      1        1  Saturday  00:15    195     64
# 2 2022-01-01 00:30:00   2022      1        1  Saturday  00:30    194     49
# 3 2022-01-01 00:45:00   2022      1        1  Saturday  00:45    162     43
# 4 2022-01-01 01:00:00   2022      1        1  Saturday  01:00    125     58
#
#    TRUK/BUS  SMP_MTR  SMP_MBL  SMP_TRK    SMP
# 0        24    148.0       39     60.0  247.0
# 1        35    156.0       64     87.5  307.5
# 2        17    155.2       49     42.5  246.7
# 3        21    129.6       43     52.5  225.1
# 4        18    100.0       58     45.0  203.0

# %%
len(df_smp)
# Out:
# 35040

# %% [markdown]
# # Group SMP Per Jam

# %%
# Round down the WAKTU column to the nearest hour
df_smp_jam = df_smp.copy()
df_smp_jam['JAM'] = df_smp['WAKTU'].dt.floor('H')

# Drop the original WAKTU column if it's not needed anymore
df_smp_jam = df_smp_jam.drop(columns=['WAKTU'])

# Format the 'JAM' column to show only hour and minute
df_smp_jam['JAM'] = df_smp_jam['JAM'].dt.strftime('%H:%M')

# Group by the rounded-down hour and sum the SMP column
df_smp_jam = df_smp_jam.groupby(['TAHUN', 'BULAN', 'TANGGAL', 'HARI', 'JAM'], as_index=False).sum()

# %%
df_smp_jam.head()
# Out:
#    TAHUN  BULAN  TANGGAL      HARI    JAM  MOTOR  MOBIL  TRUK/BUS  SMP_MTR  \
# 0   2022      1        1  Saturday  00:00    736    195        97    588.8
# 1   2022      1        1  Saturday  01:00    521    201        74    416.8
# 2   2022      1        1  Saturday  02:00    357    178        66    285.6
# 3   2022      1        1  Saturday  03:00    322    160        53    257.6
# 4   2022      1        1  Saturday  04:00    224    118        63    179.2
#
#    SMP_MBL  SMP_TRK     SMP
# 0      195    242.5  1026.3
# 1      201    185.0   802.8
# 2      178    165.0   628.6
# 3      160    132.5   550.1
# 4      118    157.5   454.7

# %%
len(df_smp_jam)
# Out:
# 8760

# %%
df_smp_jam.to_excel('../Data/Preprocessing/' + path + '/8_smp_jam_' + file + '.xlsx', index=False)

# %% [markdown]
# # Group SMP Per Hari

# %%
df_smp_hari = df_smp_jam.copy()

# %%
df_smp_hari = df_smp_hari.drop(columns=['JAM'])

# %%
df_smp_hari = df_smp_hari.groupby(['TAHUN', 'BULAN', 'TANGGAL', 'HARI'], as_index=False).sum()

# %%
df_smp_hari['RT_JAM'] = df_smp_hari['SMP']/24

# %%
df_smp_hari.head()
# Out:
#    TAHUN  BULAN  TANGGAL       HARI  MOTOR  MOBIL  TRUK/BUS  SMP_MTR  SMP_MBL  \
# 0   2022      1        1   Saturday  15147   5951      2978  12117.6     5951
# 1   2022      1        2     Sunday  13361   6315      2660  10688.8     6315
# 2   2022      1        3     Monday  12848   6856      4215  10278.4     6856
# 3   2022      1        4    Tuesday  11497   6570      5866   9197.6     6570
# 4   2022      1        5  Wednesday  11686   7493      7800   9348.8     7493
#
#    SMP_TRK      SMP       RT_JAM
# 0   7445.0  25513.6  1063.066667
# 1   6650.0  23653.8   985.575000
# 2  10537.5  27671.9  1152.995833
# 3  14665.0  30432.6  1268.025000
# 4  19500.0  36341.8  1514.241667

# %%
len(df_smp_hari)
# Out:
# 365

# %%
df_smp_hari.to_excel('../Data/Preprocessing/' + path + '/8_smp_hari_' + file + '.xlsx', index=False)

# %% [markdown]
# # Group SMP Per Bulan

# %%
df_smp_bln = df_smp_hari.copy()

# %%
df_smp_bln = df_smp_bln.drop(columns=['TANGGAL','HARI','RT_JAM'])

# %%
df_smp_bln.head()
# Out:
#    TAHUN  BULAN  MOTOR  MOBIL  TRUK/BUS  SMP_MTR  SMP_MBL  SMP_TRK      SMP
# 0   2022      1  15147   5951      2978  12117.6     5951   7445.0  25513.6
# 1   2022      1  13361   6315      2660  10688.8     6315   6650.0  23653.8
# 2   2022      1  12848   6856      4215  10278.4     6856  10537.5  27671.9
# 3   2022      1  11497   6570      5866   9197.6     6570  14665.0  30432.6
# 4   2022      1  11686   7493      7800   9348.8     7493  19500.0  36341.8

# %%
df_smp_bln = df_smp_bln.groupby(['TAHUN', 'BULAN'], as_index=False).sum()
df_smp_bln['LHR_BLN'] = df_smp_bln.apply(lambda row: row['SMP'] / days_in_month(int(row['TAHUN']), int(row['BULAN'])), axis=1)

# %%
df_smp_bln.head()
# Out:
#    TAHUN  BULAN   MOTOR   MOBIL  TRUK/BUS   SMP_MTR  SMP_MBL   SMP_TRK  \
# 0   2022      1  362845  229381    174095  290276.0   229381  435237.5
# 1   2022      2  303163  172839    153117  242530.4   172839  382792.5
# 2   2022      3  366223  197789    178884  292978.4   197789  447210.0
# 3   2022      4  343695  186387    173739  274956.0   186387  434347.5
# 4   2022      5  481667  283073    167316  385333.6   283073  418290.0
#
#          SMP       LHR_BLN
# 0   954894.5  30803.048387
# 1   798161.9  28505.782143
# 2   937977.4  30257.335484
# 3   895690.5  29856.350000
# 4  1086696.6  35054.729032

# %%
len(df_smp_bln)
# Out:
# 12

# %%
df_smp_bln.to_excel('../Data/Preprocessing/' + path + '/8_smp_bulan_' + file + '.xlsx', index=False)

# %% [markdown]
# # Menghitung LHRT (AADT)

# %%
# Menghitung AADT
aadts = {}
for month in df_smp_hari['BULAN'].unique():
    monthly_data = df_smp_hari[df_smp_hari['BULAN'] == month]
    weekly_averages = []
    for day in monthly_data['HARI'].unique():
        daily_data = monthly_data[monthly_data['HARI'] == day]
        daily_average = daily_data['SMP'].mean()
        weekly_averages.append(daily_average)
    monthly_average = np.mean(weekly_averages)
    aadts[month] = monthly_average

# Mengubah dictionary menjadi DataFrame
aadts_df = pd.DataFrame(list(aadts.items()), columns=['BULAN', 'LHR_BLN'])

# %%
aadts_df.head(12)
# Out:
#     BULAN       LHR_BLN
# 0       1  30964.541429
# 1       2  28505.782143
# 2       3  30154.757143
# 3       4  29676.492857
# 4       5  35009.897143
# 5       6  30836.802857
# 6       7  32127.995714
# 7       8  31288.851429
# 8       9  30786.148571
# 9      10  29870.282857
# 10     11  29003.058571
# 11     12  29537.649286

# %%
aadt = aadts_df['LHR_BLN'].mean()
print(f"Estimated AADT is {aadt}")
# Out:
# Estimated AADT is 30646.854999999996

# %%
aadt_simple = df_smp_hari['SMP'].mean()
print(f"Estimated AADT is {aadt_simple}")
# Out:
# Estimated AADT is 30694.26739726027

# %%
aadts_df.to_excel('../Data/Preprocessing/' + path + '/8_aadt_bulan_' + file + '.xlsx', index=False)

# %%
aadts_df.head()
# Out:
#    BULAN       LHR_BLN
# 0      1  30964.541429
# 1      2  28505.782143
# 2      3  30154.757143
# 3      4  29676.492857
# 4      5  35009.897143

# %% [markdown]
# # Menghitung Faktor K

# %%
df_k = df_smp_jam.copy()
df_k = df_k.sort_values('SMP', ascending=False)
df_k = df_k.reset_index(drop=True)

# %%
df_k.head()
# Out:
#    TAHUN  BULAN  TANGGAL     HARI    JAM  MOTOR  MOBIL  TRUK/BUS  SMP_MTR  \
# 0   2022      5        1   Sunday  06:00   5179    590       137   4143.2
# 1   2022      5        1   Sunday  00:00   4317    472        57   3453.6
# 2   2022      5        3  Tuesday  09:00   3054   1010       235   2443.2
# 3   2022      5        3  Tuesday  10:00   3007   1093       195   2405.6
# 4   2022      5        1   Sunday  02:00   4292    418        34   3433.6
#
#    SMP_MBL  SMP_TRK     SMP
# 0      590    342.5  5075.7
# 1      472    142.5  4068.1
# 2     1010    587.5  4040.7
# 3     1093    487.5  3986.1
# 4      418     85.0  3936.6

# %%
# Assuming df_k_200 is already sorted by 'SMP'
fig, ax = plt.subplots(figsize=(10, 6))

# Plot the entire SMP data
ax.plot(df_k.index, df_k['SMP'], linestyle='-', color='blue', label='SMP')

# Highlight the 30th, 50th, and 100th highest volumes
k30_point = ax.plot(29, df_k.iloc[29]['SMP'], 'ro', label=f'SMP-30: {df_k.iloc[29]["SMP"]:.2f}')
k50_point = ax.plot(49, df_k.iloc[49]['SMP'], 'go', label=f'SMP-50: {df_k.iloc[49]["SMP"]:.2f}')
k100_point = ax.plot(99, df_k.iloc[99]['SMP'], 'yo', label=f'SMP-100: {df_k.iloc[99]["SMP"]:.2f}')

# Setting plot titles and labels
ax.set_title('SMP per Hour Indexed')
ax.set_xlabel('Index')
ax.set_ylabel('SMP')
ax.grid(True)

# Adding legend
ax.legend()

# Show the plot
plt.xticks(rotation=45)
plt.tight_layout()
plt.savefig('../Data/Visualisasi/Losarang/2022/8_smp_hour_sort_' + file + '.png')
plt.show()

# %%
df_k_200 = df_k.head(200)

# %%
# Assuming df_k_200 is already sorted by 'SMP'
fig, ax = plt.subplots(figsize=(10, 6))

# Plot the entire SMP data
ax.plot(df_k_200.index, df_k_200['SMP'], linestyle='-', color='blue', label='SMP')

# Highlight the 30th, 50th, and 100th highest volumes
k30_point = ax.plot(29, df_k_200.iloc[29]['SMP'], 'ro', label=f'SMP-30: {df_k_200.iloc[29]["SMP"]:.2f}')
k50_point = ax.plot(49, df_k_200.iloc[49]['SMP'], 'go', label=f'SMP-50: {df_k_200.iloc[49]["SMP"]:.2f}')
k100_point = ax.plot(99, df_k_200.iloc[99]['SMP'], 'yo', label=f'SMP-100: {df_k_200.iloc[99]["SMP"]:.2f}')

# Setting plot titles and labels
ax.set_title('SMP per Hour Indexed')
ax.set_xlabel('Index')
ax.set_ylabel('SMP')
ax.grid(True)

# Adding legend
ax.legend()

# Show the plot
plt.xticks(rotation=45)
plt.tight_layout()
plt.savefig('../Data/Visualisasi/Losarang/2022/8_smp_hour_sort_200_' + file + '.png')
plt.show()

# %%
faktor_k = {}

# Assuming df_k is sorted by 'SMP' in descending order and AADT is predefined
K_30 = (df_k.loc[29, 'SMP'] / aadt) * 100  # Accessing the 30th highest value
K_50 = (df_k.loc[49, 'SMP'] / aadt) * 100  # Accessing the 50th highest value
K_100 = (df_k.loc[99, 'SMP'] / aadt) * 100  # Accessing the 100th highest value

faktor_k['K-30'] = f"{K_30:.2f}%"
faktor_k['K-50'] = f"{K_50:.2f}%"
faktor_k['K-100'] = f"{K_100:.2f}%"

# Mengubah dictionary menjadi DataFrame
faktor_k_df = pd.DataFrame(list(faktor_k.items()), columns=['K', 'Factor'])

# %%
faktor_k_df.head()
# Out:
#        K Factor
# 0   K-30  9.37%
# 1   K-50  8.71%
# 2  K-100  8.00%

# %%
faktor_k_df.to_excel('../Data/Preprocessing/' + path + '/8_faktor_k_' + file + '.xlsx', index=False)

# %% [markdown]
# # Menghitung Proporsi Harian Terhadap Tahunan

# %%
df_pro_hari_thn = df_smp_hari.copy()
df_pro_hari_thn['PRO_HARI_THN'] = df_pro_hari_thn['SMP']/aadt
df_pro_hari_thn = df_pro_hari_thn[['TAHUN','BULAN','TANGGAL','SMP','PRO_HARI_THN']]

# %%
df_pro_hari_thn.head()
# Out:
#    TAHUN  BULAN  TANGGAL      SMP  PRO_HARI_THN
# 0   2022      1        1  25513.6      0.832503
# 1   2022      1        2  23653.8      0.771818
# 2   2022      1        3  27671.9      0.902928
# 3   2022      1        4  30432.6      0.993009
# 4   2022      1        5  36341.8      1.185825

# %%
df_pro_hari_thn.to_excel('../Data/Preprocessing/' + path + '/8_pro_hari_thn_' + file + '.xlsx', index=False)

# %% [markdown]
# # Menghitung Proporsi Harian Terhadap Bulanan

# %%
data_gabungan = pd.merge(aadts_df[['BULAN','LHR_BLN']], df_smp_hari, on=['BULAN'])

# %%
data_gabungan = data_gabungan[['TAHUN', 'BULAN','TANGGAL','HARI','SMP','LHR_BLN']]

# %%
data_gabungan['PRO_HARI_BLN'] = data_gabungan['SMP']/aadt

# %%
data_gabungan.head()
# Out:
#    TAHUN  BULAN  TANGGAL       HARI      SMP       LHR_BLN  PRO_HARI_BLN
# 0   2022      1        1   Saturday  25513.6  30964.541429      0.832503
# 1   2022      1        2     Sunday  23653.8  30964.541429      0.771818
# 2   2022      1        3     Monday  27671.9  30964.541429      0.902928
# 3   2022      1        4    Tuesday  30432.6  30964.541429      0.993009
# 4   2022      1        5  Wednesday  36341.8  30964.541429      1.185825

# %%
data_gabungan.to_excel('../Data/Preprocessing/' + path + '/8_pro_hari_bln_' + file + '.xlsx', index=False)

# %% [markdown]
# # Menghitung Proporsi Bulanan Terhadap Tahunan

# %%
df_pro_bul_thn = df_smp_bln.copy()
df_pro_bul_thn['PRO_BLN_THN'] = df_smp_bln['LHR_BLN']/aadt
df_pro_bul_thn = df_pro_bul_thn[['TAHUN','BULAN','LHR_BLN','PRO_BLN_THN']]

# %%
df_pro_bul_thn.head(12)
# Out:
#     TAHUN  BULAN       LHR_BLN  PRO_BLN_THN
# 0    2022      1  30803.048387     1.005097
# 1    2022      2  28505.782143     0.930137
# 2    2022      3  30257.335484     0.987290
# 3    2022      4  29856.350000     0.974206
# 4    2022      5  35054.729032     1.143828
# 5    2022      6  30896.200000     1.008136
# 6    2022      7  32148.970968     1.049014
# 7    2022      8  31246.683871     1.019572
# 8    2022      9  30813.236667     1.005429
# 9    2022     10  29737.474194     0.970327
# 10   2022     11  29078.406667     0.948822
# 11   2022     12  29652.400000     0.967551

# %%
df_pro_bul_thn.to_excel('../Data/Preprocessing/' + path + '/8_pro_bln_thn_' + file + '.xlsx', index=False)
