# %%
import os
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
def read_excel(path):
    return pd.read_excel(path)

# %%
path_1 = '../Data/Preprocessing/Data Losarang/2023/3_lhrt_losarang_2023.xlsx'

df = read_excel(path_1)
df.head()
# Out:
#      HARI    JAM  MOTOR  MOBIL  TRUK/BUS  SMP_MTR  SMP_MBL  SMP_TRK   SMP
# 0  Friday  00:00    195    259       401      156      259     1004  1418
# 1  Friday  01:00    169    239       357      135      239      892  1266
# 2  Friday  02:00    151    224       312      122      224      782  1125
# 3  Friday  03:00    132    213       286      106      213      714  1033
# 4  Friday  04:00    119    186       273       95      186      684   966

# %%
def normalisasi(df, HARI):
    data = df[df['HARI'] == HARI].copy() 
    data.loc[:, 'SMP_zscore'] = (data['SMP'] - data['SMP'].min()) / (data['SMP'].max() - data['SMP'].min())
    return data

# %%
day_names = ['Monday','Tuesday','Wednesday','Thursday','Friday','Saturday','Sunday']
day_names
# Out:
# ['Monday', 'Tuesday', 'Wednesday', 'Thursday', 'Friday', 'Saturday', 'Sunday']

# %%
# List untuk menampung hasil normalisasi
df_list = []

# Iterasi untuk setiap hari dan normalisasi data
for day in day_names:
    df_normalized = normalisasi(df, day)
    df_list.append(df_normalized)

# Menggabungkan kembali hasilnya menjadi satu DataFrame
df_result = pd.concat(df_list)

# %%
df = df_result.copy()
df.to_excel('../Data/Preprocessing/Data Losarang/2023/4_lhrt_normalisasi_losarang_2023.xlsx', index=False)
df.head(48)
# Out:
#         HARI    JAM  MOTOR  MOBIL  TRUK/BUS  SMP_MTR  SMP_MBL  SMP_TRK   SMP  \
# 24    Monday  00:00    199    202       172      160      202      431   792
# 25    Monday  01:00    168    181       157      135      181      392   708
# 26    Monday  02:00    144    165       144      115      165      358   638
# 27    Monday  03:00    127    150       141      101      150      354   605
# 28    Monday  04:00    132    136       121      106      136      301   543
# 29    Monday  05:00    265    154       125      212      154      312   679
# 30    Monday  06:00    766    221       196      613      221      488  1323
# 31    Monday  07:00   1016    270       188      813      270      471  1554
# 32    Monday  08:00    822    266       172      657      266      429  1354
# 33    Monday  09:00    790    266       148      632      266      369  1267
# 34    Monday  10:00    761    273       165      609      273      413  1293
# 35    Monday  11:00    700    283       221      559      283      550  1392
# 36    Monday  12:00    648    280       250      518      280      623  1423
# 37    Monday  13:00    654    301       250      524      301      628  1451
# 38    Monday  14:00    713    306       305      572      306      763  1641
# 39    Monday  15:00    769    313       342      616      313      855  1783
# 40    Monday  16:00   1048    346       347      839      346      866  2050
# 41    Monday  17:00   1108    361       429      886      361     1073  2322
# 42    Monday  18:00    719    330       350      575      330      876  1783
# 43    Monday  19:00    555    290       320      444      290      798  1532
# 44    Monday  20:00    535    273       315      428      273      790  1491
# 45    Monday  21:00    502    287       405      401      287     1014  1704
# 46    Monday  22:00    361    273       442      288      273     1104  1667
# 47    Monday  23:00    230    284       449      184      284     1121  1589
# 120  Tuesday  00:00    234    325       427      188      325     1068  1581
# 121  Tuesday  01:00    232    361       437      185      361     1093  1638
# 122  Tuesday  02:00    146    272       356      117      272      891  1278
# 123  Tuesday  03:00    130    245       323      104      245      807  1158
# 124  Tuesday  04:00    118    203       301       94      203      752  1051
# 125  Tuesday  05:00    220    193       305      176      193      762  1131
# 126  Tuesday  06:00    622    229       392      497      229      980  1705
# 127  Tuesday  07:00    900    276       364      720      276      909  1905
# 128  Tuesday  08:00    761    280       298      608      280      745  1633
# 129  Tuesday  09:00    732    276       267      586      276      666  1528
# 130  Tuesday  10:00    691    269       302      552      269      753  1574
# 131  Tuesday  11:00    615    297       354      491      297      887  1676
# 132  Tuesday  12:00    571    288       375      456      288      937  1683
# 133  Tuesday  13:00    613    297       328      490      297      823  1610
# 134  Tuesday  14:00    653    310       360      523      310      900  1733
# 135  Tuesday  15:00    695    296       395      555      296      986  1837
# 136  Tuesday  16:00   1051    317       366      841      317      915  2072
# 137  Tuesday  17:00   1094    333       472      875      333     1180  2387
# 138  Tuesday  18:00    755    358       398      603      358      994  1955
# 139  Tuesday  19:00    563    292       351      450      292      880  1622
# 140  Tuesday  20:00    514    276       337      412      276      841  1528
# 141  Tuesday  21:00    477    289       408      382      289     1021  1692
# 142  Tuesday  22:00    316    297       457      252      297     1142  1694
# 143  Tuesday  23:00    238    294       459      190      294     1148  1634
#
#      SMP_zscore
# 24     0.139966
# 25     0.092749
# 26     0.053401
# 27     0.034851
# 28     0.000000
# 29     0.076447
# 30     0.438449
# 31     0.568297
# 32     0.455874
# 33     0.406970
# 34     0.421585
# 35     0.477234
# 36     0.494660
# 37     0.510399
# 38     0.617201
# 39     0.697021
# 40     0.847105
# 41     1.000000
# 42     0.697021
# 43     0.555930
# 44     0.532884
# 45     0.652614
# 46     0.631816
# 47     0.587971
# 120    0.396707
# 121    0.439371
# 122    0.169910
# 123    0.080090
# 124    0.000000
# 125    0.059880
# 126    0.489521
# 127    0.639222
# 128    0.435629
# 129    0.357036
# 130    0.391467
# 131    0.467814
# 132    0.473054
# 133    0.418413
# 134    0.510479
# 135    0.588323
# 136    0.764222
# 137    1.000000
# 138    0.676647
# 139    0.427395
# 140    0.357036
# 141    0.479790
# 142    0.481287
# 143    0.436377

# %%
# Urutkan hari secara berurut
urutan_hari = ['Monday', 'Tuesday', 'Wednesday', 'Thursday', 'Friday', 'Saturday', 'Sunday']
df['HARI'] = pd.Categorical(df['HARI'], categories=urutan_hari, ordered=True)

# Iterasi melalui hari dan plot setiap hari
for i, hari in enumerate(urutan_hari):
    fig = plt.subplots(figsize=(12, 8))
    data_harian = df[df['HARI'] == hari]  # Filter data per hari
    sns.lineplot(x=data_harian['JAM'], y=data_harian['SMP'])
    plt.title('Losarang 2023 - ' + hari, fontsize=16)
    plt.xticks(rotation=45)
    plt.grid(True)
    plt.tight_layout()
    plt.savefig('../Data/Visualisasi/Losarang/2023/4_'+str(i+1)+'_'+hari+'_losarang_2023.png')
    plt.show()

# %%
# Urutkan hari secara berurut
urutan_hari = ['Monday', 'Tuesday', 'Wednesday', 'Thursday', 'Friday', 'Saturday', 'Sunday']
df['HARI'] = pd.Categorical(df['HARI'], categories=urutan_hari, ordered=True)

# Iterasi melalui hari dan plot setiap hari
for i, hari in enumerate(urutan_hari):
    fig = plt.subplots(figsize=(12, 8))
    data_harian = df[df['HARI'] == hari]  # Filter data per hari
    sns.lineplot(x=data_harian['JAM'], y=data_harian['SMP_zscore'])
    plt.title('Losarang 2023 (Normalisasi) - ' + hari, fontsize=16)
    plt.xticks(rotation=45)
    plt.tight_layout()
    plt.grid(True)
    plt.savefig('../Data/Visualisasi/Losarang/2023/4_'+str(i+1)+'_'+hari+'_normalisasi_losarang_2023.png')
    plt.show()

# %%
# Ubah 'JAM' menjadi tipe waktu dan 'HARI' menjadi kategori berurut
urutan_hari = ['Monday', 'Tuesday', 'Wednesday', 'Thursday', 'Friday', 'Saturday', 'Sunday']
df['HARI'] = pd.Categorical(df['HARI'], categories=urutan_hari, ordered=True)
# df['JAM'] = pd.to_datetime(df['JAM'], format='%H:%M').dt.time

# Membuat visualisasi menggunakan Seaborn lineplot
plt.figure(figsize=(12, 8))
sns.lineplot(x=df['JAM'].astype(str), y=df['SMP'], hue=df['HARI'])

# Menambahkan label dan judul
plt.title('SMP per Hari dan Jam - Losarang 2023', fontsize=16)
plt.xlabel('Jam', fontsize=12)
plt.ylabel('SMP', fontsize=12)
plt.xticks(rotation=45)
plt.grid(True)

# Menampilkan visualisasi
plt.tight_layout()
plt.savefig('../Data/Visualisasi/Losarang/2023/4_harian_losarang_2023.png')
plt.show()

# %%
# Ubah 'JAM' menjadi tipe waktu dan 'HARI' menjadi kategori berurut
urutan_hari = ['Monday', 'Tuesday', 'Wednesday', 'Thursday', 'Friday', 'Saturday', 'Sunday']
df['HARI'] = pd.Categorical(df['HARI'], categories=urutan_hari, ordered=True)
# df['JAM'] = pd.to_datetime(df['JAM'], format='%H:%M').dt.time

# Membuat visualisasi menggunakan Seaborn lineplot
plt.figure(figsize=(12, 8))
sns.lineplot(x=df['JAM'].astype(str), y=df['SMP_zscore'], hue=df['HARI'])

# Menambahkan label dan judul
plt.title('SMP Normalisasi per Hari dan Jam - Losarang 2023', fontsize=16)
plt.xlabel('Jam', fontsize=12)
plt.ylabel('SMP', fontsize=12)
plt.xticks(rotation=45)
plt.grid(True)

# Menampilkan visualisasi
plt.tight_layout()
plt.savefig('../Data/Visualisasi/Losarang/2023/4_harian_normalisasi_losarang_2023.png')
plt.show()
